# %%
from docx import Document
from docx.shared import RGBColor

def get_highlight_color(run):
    """Get the highlight color of a run."""
    if run.font.highlight_color:
        return run.font.highlight_color  # Word highlight color index
    elif run.font.color and run.font.color.rgb:
        return run.font.color.rgb  # RGB color
    return None

def extract_peco_highlights_from_tables(doc_path):
    """Extract highlighted text from 'PECO statement' rows in tables."""
    doc = Document(doc_path)
    tables_data = []

    annotation_map = {
        'PINK (5)': 'Population',
        'BRIGHT_GREEN (4)': 'Exposure',
        'TURQUOISE (3)': 'Comparator',
        'YELLOW (7)': 'Outcome'
    }

    for table in doc.tables:
        table_dict = {}
        for row in table.rows:
            # doc title
            if "Title of manuscript" in row.cells[0].text.strip():
                table_dict["doc_title"] = row.cells[-1].text.strip()
            
            # doc name
            if "Last name of first author" in row.cells[0].text.strip():
                table_dict["doc_lastauthorname"] = row.cells[-1].text.strip()
            
            # doc year
            if "Year of publication" in row.cells[0].text.strip():
                table_dict["doc_year"] = row.cells[-1].text.strip()
            
            # url
            if "URL of HTML manuscript" in row.cells[0].text.strip():    
                table_dict["doc_url"] = row.cells[-1].text.strip()

            # section
            if "Section PECO statement is in" in row.cells[0].text.strip():
                table_dict["doc_peco_section"] = row.cells[-1].text.strip()

            # PECO statement
            if "PECO statement" in row.cells[0].text.strip():  # Check for PECO row
                peco_cell = row.cells[-1]  # Assume PECO text is in the 2nd column
                color_text_map = {}

                for para in peco_cell.paragraphs:
                    for run in para.runs:
                        color = get_highlight_color(run)
                        text = run.text.strip()
                        if color and text:  # Only include highlighted text
                            color_key = str(color)
                            if color_key in annotation_map:
                                color_key = annotation_map[color_key]
                                if color_key not in color_text_map:
                                    color_text_map[color_key] = []
                                color_text_map[color_key].append(text)

                table_dict["peco_elements"] = color_text_map
        if table_dict:
            tables_data.append(table_dict)

    return tables_data

doc_path = "data/PECO-examples_merged-example.docx"  
result = extract_peco_highlights_from_tables(doc_path)

# Print the structured output
for i, table in enumerate(result, 1):
    print(f"Table {i}:")
    for color, texts in table["peco_elements"].items():
        print(f"  Color: {color}, Text: {', '.join(texts)}")
    print("-" * 50)

# %%
result

# %%
from keybert import KeyBERT

kw_model = KeyBERT()

def extract_keyphrases(text):
    # Extract keyphrases with n-grams up to 2 words
    keywords = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 2), stop_words="english")
    return [kw[0] for kw in keywords]

# Example
text = "compared to relatively lower or higher temperatures"
keyphrases = extract_keyphrases(text)
print(keyphrases)  # Output: ['higher temperatures', 'lower temperatures']

# %%
from keybert import KeyBERT

# %% [markdown]
# The following script is from https://github.com/IHTSDO/SNOMED-in-5-minutes/blob/master/python3-examples/examples.py
#
# True to form, the starter script failed with an IP ban error code when I attempted to run it without modifying `user_agent` first.

# %%
# This script uses the Snowstorm SNOMED-CT API. A standardised FHIR API is also available.

# Note that we recommend running your own Snowstorm instance for heavy script use.
# See https://github.com/IHTSDO/snowstorm

from urllib.request import urlopen, Request
from urllib.parse import quote
import json

baseUrl = 'https://browser.ihtsdotools.org/snowstorm/snomed-ct'
edition = 'MAIN'
version = '2019-07-31'

# IMPORTANT! You must update this user agent to avoid having your IP banned for 24 hours.
# Replace with a contact email so that we can contact you if your script causes excessive load on the public server
# For example: user_agent = 'example@example.com'
user_agent = 'joelchan@umd.edu'

def urlopen_with_header(url):
    # adds User-Agent header otherwise urlopen on its own gets an IP blocked response
    req = Request(url)
    req.add_header('User-Agent', user_agent)
    return urlopen(req)

#Prints fsn of a concept
def getConceptById(id):
    url = baseUrl + '/browser/' + edition + '/' + version + '/concepts/' + id
    response = urlopen_with_header(url).read()
    data = json.loads(response.decode('utf-8'))

    print (data['fsn']['term'])

#Prints description by id
def getDescriptionById(id):
    url = baseUrl + '/' + edition + '/' + version + '/descriptions/' + id
    response = urlopen_with_header(url).read()
    data = json.loads(response.decode('utf-8'))

    print (data['term'])

#Prints number of concepts with descriptions containing the search term
def getConceptsByString(searchTerm):
    url = baseUrl + '/browser/' + edition + '/' + version + '/concepts?term=' + quote(searchTerm) + '&activeFilter=true&offset=0&limit=50'
    response = urlopen_with_header(url).read()
    data = json.loads(response.decode('utf-8'))

    print (data['total'])

#Prints number of descriptions containing the search term with a specific semantic tag
def getDescriptionsByStringFromProcedure(searchTerm, semanticTag):
    url = baseUrl + '/browser/' + edition + '/' + version + '/descriptions?term=' + quote(searchTerm) + '&conceptActive=true&semanticTag=' + quote(semanticTag) + '&groupByConcept=false&searchMode=STANDARD&offset=0&limit=50'
    response = urlopen_with_header(url).read()
    data = json.loads(response.decode('utf-8'))

    print (data['totalElements'])
    
 #Prints snomed code for searched disease or symptom
def getSnomedCodeSimilar(searchTerm):
    url = baseUrl + '/browser/' + edition + '/' + version + '/descriptions?term=' + quote(searchTerm) + '&conceptActive=true&groupByConcept=false&searchMode=STANDARD&offset=0&limit=50'
    response = urlopen_with_header(url).read()
    data = json.loads(response.decode('utf-8'))

    for term in data['items']:
      if searchTerm in term['term']:
        print("{} : {}".format(term['term'], term['concept']['conceptId']))
 
def getSnomedCode(searchTerm):
    url = baseUrl + '/browser/' + edition + '/' + version + '/descriptions?term=' + quote(searchTerm) + '&conceptActive=true&groupByConcept=false&searchMode=STANDARD&offset=0&limit=50'
    response = urlopen_with_header(url).read()
    data = json.loads(response.decode('utf-8'))

    for term in data['items']:
      if searchTerm == term['term']:
        print("{} : {}".format(term['term'], term['concept']['conceptId']))

# %%
getConceptById('109152007')
getDescriptionById('679406011')
getConceptsByString('heart attack')
getDescriptionsByStringFromProcedure('heart', 'procedure')
getSnomedCodeSimilar('Headache')
getSnomedCode('Bleeding from nose')
# Out:
# Bilirubin test kit (physical object)
# Methylphenyltetrahydropyridine (substance)
# 471023
# 864
# Headache : 25064002
# Headache, NOS : 25064002
# HA - Headache : 25064002
# Headache site : 162297001
# Headache stick : 462677001
# Headache clinic : 702864009
# Headache disorder : 230461009
# Headache (finding) : 25064002
# Headache character : 162306000
# Bleeding from nose : 249366005

# %% [markdown]
# Failed code from Claude

# %%
import requests
import pandas as pd

class OntServerConnector:
    def __init__(self, base_url='https://ontoserver.csiro.au/fhir'):
        """
        Initialize connection to Ontoserver's public SNOMED CT FHIR endpoint
        
        :param base_url: Base URL for Ontoserver FHIR endpoint
        """
        self.base_url = base_url
        self.headers = {
            'Accept': 'application/fhir+json'
        }
    
    def search_snomed_concepts(self, search_term, limit=10):
        """
        Search SNOMED CT concepts using Ontoserver
        
        :param search_term: Term to search for
        :param limit: Maximum number of results to return
        :return: DataFrame of SNOMED concepts
        """
        endpoint = f"{self.base_url}/CodeSystem/$lookup"
        
        params = {
            'system': 'http://snomed.info/sct',
            'property': 'designation',
            'filter': search_term,
            '_count': limit
        }
        
        try:
            response = requests.get(endpoint, 
                                    headers=self.headers, 
                                    params=params)
            response.raise_for_status()
            
            results = response.json()
            
            # Parse FHIR search results
            concepts = []
            for entry in results.get('parameter', []):
                if entry.get('name') == 'result':
                    part = entry.get('part', [])
                    concept = {
                        'code': next((p['valueCode'] for p in part if p['name'] == 'code'), None),
                        'display': next((p['valueString'] for p in part if p['name'] == 'display'), None)
                    }
                    concepts.append(concept)
            
            return pd.DataFrame(concepts)
        
        except requests.RequestException as e:
            print(f"Error searching SNOMED concepts: {e}")
            return pd.DataFrame()
    
    def get_concept_details(self, concept_id):
        """
        Retrieve detailed information for a specific SNOMED concept
        
        :param concept_id: SNOMED CT Concept ID
        :return: Dictionary of concept details
        """
        endpoint = f"{self.base_url}/CodeSystem/$lookup"
        
        params = {
            'system': 'http://snomed.info/sct',
            'code': concept_id
        }
        
        try:
            response = requests.get(endpoint, 
                                    headers=self.headers, 
                                    params=params)
            response.raise_for_status()
            
            return response.json()
        
        except requests.RequestException as e:
            print(f"Error retrieving concept details: {e}")
            return {}
# Out:
# /Users/joelchan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/joelchan/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# I think the public fhir endpoint is no longer up.

# %%
 # Initialize Ontoserver connector
ontoserver = OntServerConnector()

# Search for concepts related to "diabetes"
diabetes_concepts = ontoserver.search_snomed_concepts("diabetes")
print("Diabetes Concepts:")
print(diabetes_concepts)

# If concepts found, get details of first concept
if not diabetes_concepts.empty:
    concept_id = diabetes_concepts.iloc[0]['code']
    concept_details = ontoserver.get_concept_details(concept_id)
    print("\nConcept Details:")
    print(concept_details)
# Out:
# Error searching SNOMED concepts: 404 Client Error: Not Found for url: https://ontoserver.csiro.au/fhir/CodeSystem/$lookup?system=http%3A%2F%2Fsnomed.info%2Fsct&property=designation&filter=diabetes&_count=10
# Diabetes Concepts:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Failed simpler code from Claude with prompt:
# > give me a much simpler and smaller starting point just so i can test connecting to the ols api
#
# base url was wrong.

# %%
import requests

def search_snomed_term(term):
    """
    Simple function to search SNOMED terms using OLS API
    
    :param term: Search term for SNOMED concepts
    :return: List of matching concepts
    """
    base_url = 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms'
    
    # Parameters for the search
    params = {
        'q': term,
        'rows': 10  # Limit to 5 results
    }
    
    try:
        # Make the API request
        response = requests.get(base_url, params=params)
        
        # Raise an exception for bad responses
        response.raise_for_status()
        
        # Parse and return the JSON results
        results = response.json()

        print(results)
        
        # Extract labels from the results
        concepts = [
            {
                'label': term_info.get('label'),
                'iri': term_info.get('iri')
            } 
            for term_info in results.get('_embedded', {}).get('terms', [])
        ]
        
        return concepts
    
    except requests.RequestException as e:
        print(f"Error connecting to OLS API: {e}")
        return []


search_term = "neurological disorders"
results = search_snomed_term(search_term)

print(f"Search results for '{search_term}':")
for concept in results:
    print(f"- {concept['label']} (IRI: {concept['iri']})")
# Out:
# {'_embedded': {'terms': [{'iri': 'http://snomed.info/id/125413009', 'lang': 'en', 'description': [], 'synonyms': [], 'annotation': {'alternative label': ['Cytoplasmic matrix alteration'], 'has_dbxref': ['CTV3:XU6Tc'], 'preferred label': ['Cytoplasmic alteration']}, 'label': 'Cytoplasmic alteration', 'ontology_name': 'snomed', 'ontology_prefix': 'SNOMED', 'ontology_iri': 'http://snomed.info/sct/900000000000207008', 'is_obsolete': False, 'term_replaced_by': None, 'is_defining_ontology': True, 'has_children': False, 'is_root': False, 'short_form': 'SNOMED_125413009', 'obo_id': 'SNOMED:125413009', 'in_subset': None, 'obo_definition_citation': None, 'obo_xref': [{'database': 'CTV3', 'id': 'XU6Tc', 'description': None, 'url': None}], 'obo_synonym': None, 'is_preferred_root': False, '_links': {'self': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125413009?lang=en'}, 'parents': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125413009/parents'}, 'ancestors': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125413009/ancestors'}, 'hierarchicalParents': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125413009/hierarchicalParents'}, 'hierarchicalAncestors': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125413009/hierarchicalAncestors'}, 'jstree': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125413009/jstree'}, 'graph': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125413009/graph'}}}, {'iri': 'http://snomed.info/id/125414003', 'lang': 'en', 'description': [], 'synonyms': [], 'annotation': {'has_dbxref': ['CTV3:XU6Td'], 'preferred label': ['Cytoplasmic aggregate']}, 'label': 'Cytoplasmic aggregate', 'ontology_name': 'snomed', 'ontology_prefix': 'SNOMED', 'ontology_iri': 'http://snomed.info/sct/900000000000207008', 'is_obsolete': False, 'term_replaced_by': None, 'is_defining_ontology': True, 'has_children': False, 'is_root': False, 'short_form': 'SNOMED_125414003', 'obo_id': 'SNOMED:125414003', 'in_subset': None, 'obo_definition_citation': None, 'obo_xref': [{'database': 'CTV3', 'id': 'XU6Td', 'description': None, 'url': None}], 'obo_synonym': None, 'is_preferred_root': False, '_links': {'self': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125414003?lang=en'}, 'parents': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125414003/parents'}, 'ancestors': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125414003/ancestors'}, 'hierarchicalParents': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125414003/hierarchicalParents'}, 'hierarchicalAncestors': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125414003/hierarchicalAncestors'}, 'jstree': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125414003/jstree'}, 'graph': {'href': 'https://www.ebi.ac.uk/ols4/api/ontologies/snomed/terms/http%253A%252F%252Fsnomed.info%252Fid%252F125414003/graph'}}}, {'iri': 'http://snomed.info/id/125415002', 'lang': 'en', 'description': [], 'synonyms': [], 'annotation': {'alternative label': ['Cytoplasmic deposition'], 'has_dbxref': ['CTV3:XU6Te'], 'preferred label': ['Cytoplasmic accumulation']}, 'label': 'Cytoplasmic accumulation', 'ontology_name': 'snomed', 'ontology_prefix': 'SNOMED', 'ontology_iri': 'http://snomed.info/sct/900000000000207008', 'is_obsolete': False, 'term_replaced_by': None, 'is_d ...
# Search results for 'neurological disorders':
# - Cytoplasmic alteration (IRI: http://snomed.info/id/125413009)
# - Cytoplasmic aggregate (IRI: http://snomed.info/id/125414003)
# - Cytoplasmic accumulation (IRI: http://snomed.info/id/125415002)
# - Cytoplasmic droplets (IRI: http://snomed.info/id/125416001)
# - Cytoplasmic macromolecular aggregate (IRI: http://snomed.info/id/125417005)
# - Cytoplasmic crystalline aggregate (IRI: http://snomed.info/id/125418000)
# - Cytoplasmic lipid aggregate (IRI: http://snomed.info/id/125419008)
# - Cytoplasmic lipid droplet alteration (IRI: http://snomed.info/id/125420002)
# - Ethyl butyl ketone (IRI: http://snomed.info/id/12542006)
# - Cytoplasmic hyalinization (morphologic abnormality) (IRI: http://snomed.info/id/125421003)
# - Myelin body formation (IRI: http://snomed.info/id/125422005)
# - Intracytoplasmic electron dense deposition (IRI: http://snomed.info/id/125423000)
# - Mitochondrial alteration (IRI: http://snomed.info/id/125424006)
# - Alteration of mitochondrial cristae (IRI: http://snomed.info/id/125425007)
# - Alteration of mitochondrial matrix (IRI: http://snomed.info/id/125426008)
# - Alteration of mitochondrial membrane (IRI: http://snomed.info/id/125427004)
# - Fused cristae (IRI: http://snomed.info/id/125428009)
# - Mitochondrial enlargement (IRI: http://snomed.info/id/125429001)
# - Giant mitochondria (IRI: http://snomed.info/id/125430006)
# - Mitochondrial vacuolation (IRI: http://snomed.info/id/125431005)

# %% [markdown]
# First working minimal version.

# %%
import requests
import json

base_url = 'https://www.ebi.ac.uk/ols4/api/search'
term = "alzheimer's"

params = {
    'q': term,
    'ontology': 'snomed',
    'rows': 20,  # Increased rows
    
}

try:
    # Make the API request
    response = requests.get(base_url, params=params)
    
    # Raise an exception for bad responses
    response.raise_for_status()
    
    # Parse the JSON results with full details
    results = response.json()
    
    # Print raw API response for diagnostics
    # print("Raw API Response:")
    # print(json.dumps(results, indent=2))
    
    # Extract detailed concept information
    concepts = []
    for term_info in results.get('response', {}).get('docs', []):
        # print(term_info)
        concept = {
            'label': term_info.get('label', 'No Label'),
            'iri': term_info.get('iri', 'No IRI'),
            'description': term_info.get('description', 'No Description'),
            'ontology_name': term_info.get('ontology_name', 'No Ontology Name'),
            'short_form': term_info.get('short_form', 'No Short Form')
        }
        concepts.append(concept)
    
    for idx, concept in enumerate(concepts, 1):
        print(f"\nResult {idx}:")
        print(f"Label: {concept['label']}")
        print(f"IRI: {concept['iri']}")
        print(f"Ontology Name: {concept['ontology_name']}")
        print(f"Description: {concept['description']}")
        print(f"Short Form: {concept['short_form']}")

except requests.RequestException as e:
    print(f"Error connecting to OLS API: {e}")
# Out:
# Result 1:
# Label: Alzheimer's disease
# IRI: http://snomed.info/id/26929004
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_26929004
#
# Result 2:
# Label: Focal Alzheimer's disease
# IRI: http://snomed.info/id/230269008
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230269008
#
# Result 3:
# Label: FH: Alzheimer's disease
# IRI: http://snomed.info/id/394877006
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_394877006
#
# Result 4:
# Label: Non-Alzheimer's progressive dysphasia
# IRI: http://snomed.info/id/230279005
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230279005
#
# Result 5:
# Label: Delusions in Alzheimer's disease
# IRI: http://snomed.info/id/141991000119109
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_141991000119109
#
# Result 6:
# Label: Alzheimer's disease society member
# IRI: http://snomed.info/id/161108005
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_161108005
#
# Result 7:
# Label: Alzheimer's Disease Assessment Scale
# IRI: http://snomed.info/id/273269001
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_273269001
#
# Result 8:
# Label: Altered behavior in Alzheimer's disease (disorder)
# IRI: http://snomed.info/id/97751000119108
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_97751000119108
#
# Result 9:
# Label: Progressive aphasia in Alzheimer's disease
# IRI: http://snomed.info/id/230280008
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230280008
#
# Result 10:
# Label: Depressed mood in Alzheimer's disease
# IRI: http://snomed.info/id/142001000119106
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_142001000119106
#
# Result 11:
# Label: Alzheimer's Disease Assessment Scale score
# IRI: http://snomed.info/id/714360001
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_714360001
#
# Result 12:
# Label: Familial Alzheimer's disease of early onset
# IRI: http://snomed.info/id/230265002
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230265002
#
# Result 13:
# Label: Familial Alzheimer's disease of late onset
# IRI: http://snomed.info/id/230267005
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230267005
#
# Result 14:
# Label: Alzheimer's disease co-occurrent with delirium
# IRI: http://snomed.info/id/142011000119109
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_142011000119109
#
# Result 15:
# Label: Assessment using Alzheimer's Disease Assessment Scale
# IRI: http://snomed.info/id/714359006
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_714359006
#
# Result 16:
# Label: Early onset Alzheimer's disease with behavioral disturbance (disorder)
# IRI: http://snomed.info/id/105421000119105
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_105421000119105
#
# Result 17:
# Label: Non-familial Alzheimer's disease of early onset
# IRI: http://snomed.info/id/230266001
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230266001
#
# Result 18:
# Label: Non-familial Alzheimer's disease of late onset
# IRI: http://snomed.info/id/230268000
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230268000
#
# Result 19:
# Label: Neurofibrillary degeneration
# IRI: http://snomed.info/id/85775002
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_85775002
#
# Result 20:
# Label: Primary degenerative dementia of the Alzheimer type, presenile onset
# IRI: http://snomed.info/id/416780008
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_416780008

# %%
print(json.dumps(results, indent=2))
# Out:
# {
#   "response": {
#     "docs": [
#       {
#         "iri": "http://snomed.info/id/276587008",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_276587008",
#         "description": [],
#         "label": "Perinatal neurological disorder",
#         "obo_id": "SNOMED:276587008",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/247384001",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_247384001",
#         "description": [],
#         "label": "Neurological pain disorder",
#         "obo_id": "SNOMED:247384001",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/397929001",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_397929001",
#         "description": [],
#         "label": "Neurological morbidity",
#         "obo_id": "SNOMED:397929001",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/240468001",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_240468001",
#         "description": [],
#         "label": "Neurological varicella",
#         "obo_id": "SNOMED:240468001",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/407626008",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_407626008",
#         "description": [],
#         "label": "Neurological disorder confirmed",
#         "obo_id": "SNOMED:407626008",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/735541006",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_735541006",
#         "description": [],
#         "label": "Dissociative neurological symptom disorder",
#         "obo_id": "SNOMED:735541006",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/398106007",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_398106007",
#         "description": [],
#         "label": "Intensive care neurological disorder",
#         "obo_id": "SNOMED:398106007",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/170691000",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_170691000",
#         "description": [],
#         "label": "Neurological disorder monitoring",
#         "obo_id": "SNOMED:170691000",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/170698006",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_170698006",
#         "description": [],
#         "label": "Neurological disorder treatment changed",
#         "obo_id": "SNOMED:170698006",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/170699003",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_170699003",
#         "description": [],
#         "label": "Neurological disorder treatment started",
#         "obo_id": "SNOMED:170699003",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/170700002",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_170700002",
#         "description": [],
#         "label": "Neurological disorder treatment stopped",
#         "obo_id": "SNOMED:170700002",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/473228008",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_473228008",
#         "description": [],
#         "label": "Neurological disorder medication review",
#         "obo_id": "SNOMED:473228008",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/243856004",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_243856004",
#         "description": [],
#         "label": "Neurological disorder monitoring status",
#         "obo_id": "SNOMED:243856004",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/240463005",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_240463005",
#         "description": [],
#         "label": "Acute neurological rabies",
#         "obo_id": "SNOMED:240463005",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/241991002",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_241991002",
#         "description": [],
#         "label": "Neurological decompression syndrome",
#         "obo_id": "SNOMED:241991002",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/724844008",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_724844008",
#         "description": [],
#         "label": "Pruritus due to neurological disorder",
#         "obo_id": "SNOMED:724844008",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/723000001",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_723000001",
#         "description": [],
#         "label": "Generalized hyperhidrosis due to neurological disorder (disorder)",
#         "obo_id": "SNOMED:723000001",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/297239000",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_297239000",
#         "description": [],
#         "label": "Family history of neurological disorder",
#         "obo_id": "SNOMED:297239000",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/724560001",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_724560001",
#         "description": [],
#         "label": "Neurological disorder due to nutrient deficiency",
#         "obo_id": "SNOMED:724560001",
#         "type": "class"
#       },
#       {
#         "iri": "http://snomed.info/id/724574008",
#         "ontology_name": "snomed",
#         "ontology_prefix": "SNOMED",
#         "short_form": "SNOMED_724574008",
#         "description": [],
#         "label": "Neurological disorder caused by ingestible alcohol",
#         "obo_id": "SNOMED:724574008",
#         "type": "class"
#       }
#     ],
#     "numFound": 77227,
#     "start": 0
#   },
#   "responseHeader": {
#     "QTime": 43,
#     "status": 0
#   },
#   "facet_counts": {
#     "facet_fields": {
#       "ontologyPreferredPrefix": [
#         "snomed",
#         "77227",
#         "19",
#         "0",
#         "addicto",
#         "0",
#         "ado",
#         "0",
#         "aeo",
#         "0",
#         "afo",
#         "0",
#         "afpo",
#         "0",
#         "agro",
#         "0",
#         "aism",
#         "0",
#         "amphx",
#         "0",
#         "apo",
#         "0",
#         "apollo_sv",
#         "0",
#         "aro",
#         "0",
#         "bao",
#         "0",
#         "bcio",
#         "0",
#         "bco",
#         "0",
#         "bfo",
#         "0",
#         "bspo",
#         "0",
#         "bto",
#         "0",
#         "cao",
#         "0",
#         "caro",
#         "0",
#         "ccf",
#         "0",
#         "cco",
#         "0",
#         "cdao",
#         "0",
#         "cdno",
#         "0",
#         "chebi",
#         "0",
#         "cheminf",
#         "0",
#         "chiro",
#         "0",
#         "chmo",
#         "0",
#         "cido",
#         "0",
#         "cio",
#         "0",
#         "cl",
#         "0",
#         "clao",
#         "0",
#         "clo",
#         "0",
#         "clyh",
#         "0",
#         "cmo",
#         "0",
#         "cmpo",
#         "0",
#         "cob",
#         "0",
#         "colao",
#         "0",
#         "covid",
#         "0",
#         "covoc",
#         "0",
#         "cpont",
#         "0",
#         "cro",
#         "0",
#         "cryoem",
#         "0",
#         "cteno",
#         "0",
#         "cvdo",
#         "0",
#         "ddanat",
#         "0",
#         "ddpheno",
#         "0",
#         "dhba",
#         "0",
#         "dicom",
#         "0",
#         "dideo",
#         "0",
#         "disdriv",
#         "0",
#         "doid",
#         "0",
#         "dron",
#         "0",
#         "duo",
#         "0",
#         "ecao",
#         "0",
#         "eco",
#         "0",
#         "ecocore",
#         "0",
#         "ecto",
#         "0",
#         "edam",
#         "0",
#         "efo",
#         "0",
#         "emapa",
#         "0",
#         "emi",
#         "0",
#         "enm",
#         "0",
#         "ensgloss",
#         "0",
#         "envo",
#         "0",
#         "epio",
#         "0",
#         "eupath",
#         "0",
#         "exo",
#         "0",
#         "fao",
#         "0",
#         "fbbi",
#         "0",
#         "fbbt",
#         "0",
#         "fbcv",
#         "0",
#         "fbdv",
#         "0",
#         "fideo",
#         "0",
#         "flopo",
#         "0",
#         "fma",
#         "0",
#         "fobi",
#         "0",
#         "foodon",
#         "0",
#         "fovt",
#         "0",
#         "fypo",
#         "0",
#         "gallont",
#         "0",
#         "gecko",
#         "0",
#         "genepio",
#         "0",
#         "geno",
#         "0",
#         "geo",
#         "0",
#         "gexo",
#         "0",
#         "go",
#         "0",
#         "gsso",
#         "0",
#         "hancestro",
#         "0",
#         "hao",
#         "0",
#         "hba",
#         "0",
#         "hcao",
#         "0",
#         "hom",
#         "0",
#         "hp",
#         "0",
#         "hsapdv",
#         "0",
#         "hso",
#         "0",
#         "htn",
#         "0",
#         "iao",
#         "0",
#         "iceo",
#         "0"
#       ],
#       "isDefiningOntology": [
#         "true",
#         "77227",
#         "false",
#         "0"
#       ],
#       "ontologyId": [
#         "snomed",
#         "77227",
#         "addicto",
#         "0",
#         "ado",
#         "0",
#         "aeo",
#         "0",
#         "aero",
#         "0",
#         "afo",
#         "0",
#         "afpo",
#         "0",
#         "agro",
#         "0",
#         "aism",
#         "0",
#         "amphx",
#         "0",
#         "apo",
#         "0",
#         "apollo_sv",
#         "0",
#         "aro",
#         "0",
#         "bao",
#         "0",
#         "bcgo",
#         "0",
#         "bcio",
#         "0",
#         "bco",
#         "0",
#         "bfo",
#         "0",
#         "bila",
#         "0",
#         "biolink",
#         "0",
#         "bspo",
#         "0",
#         "bto",
#         "0",
#         "cao",
#         "0",
#         "caro",
#         "0",
#         "ccf",
#         "0",
#         "cco",
#         "0",
#         "cdao",
#         "0",
#         "cdno",
#         "0",
#         "ceph",
#         "0",
#         "chebi",
#         "0",
#         "cheminf",
#         "0",
#         "chiro",
#         "0",
#         "chmo",
#         "0",
#         "cido",
#         "0",
#         "cio",
#         "0",
#         "cl",
#         "0",
#         "clao",
#         "0",
#         "clo",
#         "0",
#         "clyh",
#         "0",
#         "cmo",
#         "0",
#         "cmpo",
#         "0",
#         "cob",
#         "0",
#         "colao",
#         "0",
#         "covoc",
#         "0",
#         "cpont",
#         "0",
#         "cro",
#         "0",
#         "cryoem",
#         "0",
#         "cteno",
#         "0",
#         "cvdo",
#         "0",
#         "dc",
#         "0",
#         "dcat",
#         "0",
#         "dcterms",
#         "0",
#         "ddanat",
#         "0",
#         "ddpheno",
#         "0",
#         "dhba",
#         "0",
#         "dicom",
#         "0",
#         "dideo",
#         "0",
#         "disdriv",
#         "0",
#         "doid",
#         "0",
#         "dpo",
#         "0",
#         "dron",
#         "0",
#         "duo",
#         "0",
#         "ecao",
#         "0",
#         "eco",
#         "0",
#         "ecocore",
#         "0",
#         "ecto",
#         "0",
#         "edam",
#         "0",
#         "efo",
#         "0",
#         "ehdaa2",
#         "0",
#         "emap",
#         "0",
#         "emapa",
#         "0",
#         "emi",
#         "0",
#         "enm",
#         "0",
#         "ensemblglossary",
#         "0",
#         "envo",
#         "0",
#         "epio",
#         "0",
#         "eupath",
#         "0",
#         "exo",
#         "0",
#         "fao",
#         "0",
#         "fbbi",
#         "0",
#         "fbbt",
#         "0",
#         "fbcv",
#         "0",
#         "fbdv",
#         "0",
#         "fbsp",
#         "0",
#         "fideo",
#         "0",
#         "fix",
#         "0",
#         "flopo",
#         "0",
#         "fma",
#         "0",
#         "fobi",
#         "0",
#         "foodon",
#         "0",
#         "fovt",
#         "0",
#         "fypo",
#         "0",
#         "gallont",
#         "0",
#         "gaz",
#         "0",
#         "gecko",
#         "0",
#         "genepio",
#         "0",
#         "geno",
#         "0",
#         "geo",
#         "0",
#         "gexo",
#         "0",
#         "go",
#         "0"
#       ],
#       "ontologyIri": [
#         "900000000000207008",
#         "77227",
#         "http",
#         "77227",
#         "sct",
#         "77227",
#         "snomed.info",
#         "77227",
#         "01",
#         "0",
#         "02",
#         "0",
#         "07",
#         "0",
#         "09",
#         "0",
#         "1",
#         "0",
#         "1.1",
#         "0",
#         "19",
#         "0",
#         "2",
#         "0",
#         "2000",
#         "0",
#         "2002",
#         "0",
#         "2004",
#         "0",
#         "2019",
#         "0",
#         "2024",
#         "0",
#         "addicto.owl",
#         "0",
#         "addictovocab.org",
#         "0",
#         "ado.owl",
#         "0",
#         "aellenhicks",
#         "0",
#         "aeo.owl",
#         "0",
#         "aero.owl",
#         "0",
#         "afo",
#         "0",
#         "afpo.owl",
#         "0",
#         "agro",
#         "0",
#         "aism.owl",
#         "0",
#         "amphx",
#         "0",
#         "amphx.owl",
#         "0",
#         "and",
#         "0",
#         "antibiotic_resistance.owl",
#         "0",
#         "apo.owl",
#         "0",
#         "apollo_sv.owl",
#         "0",
#         "bao",
#         "0",
#         "bao_complete.owl",
#         "0",
#         "bcgo.owl",
#         "0",
#         "bcio.owl",
#         "0",
#         "bco.owl",
#         "0",
#         "bfo.owl",
#         "0",
#         "bican.org",
#         "0",
#         "bila.owl",
#         "0",
#         "bio.scai.fraunhofer.de",
#         "0",
#         "biolink",
#         "0",
#         "biomodels.net",
#         "0",
#         "bspo.owl",
#         "0",
#         "bto.owl",
#         "0",
#         "cao.owl",
#         "0",
#         "caro.owl",
#         "0",
#         "ccf",
#         "0",
#         "cco_",
#         "0",
#         "cdao.owl",
#         "0",
#         "cdno.owl",
#         "0",
#         "ceph.owl",
#         "0",
#         "champ",
#         "0",
#         "chebi.owl",
#         "0",
#         "cheminf.owl",
#         "0",
#         "chiro.owl",
#         "0",
#         "chmo.owl",
#         "0",
#         "cido.owl",
#         "0",
#         "cio.owl",
#         "0",
#         "cl.owl",
#         "0",
#         "clao.owl",
#         "0",
#         "clo",
#         "0",
#         "clo_merged.owl",
#         "0",
#         "clyh",
#         "0",
#         "clyh.owl",
#         "0",
#         "cmo.owl",
#         "0",
#         "cmpo",
#         "0",
#         "cmpo.owl",
#         "0",
#         "cob.owl",
#         "0",
#         "colao.owl",
#         "0",
#         "collection",
#         "0",
#         "core",
#         "0",
#         "covid",
#         "0",
#         "covoc.owl",
#         "0",
#         "cpont",
#         "0",
#         "cpont.owl",
#         "0",
#         "cro.owl",
#         "0",
#         "cryoem.owl",
#         "0",
#         "cteno.owl",
#         "0",
#         "cvdo.owl",
#         "0",
#         "data",
#         "0",
#         "dc",
#         "0",
#         "dcat",
#         "0",
#         "dcm",
#         "0",
#         "ddanat.owl",
#         "0",
#         "ddpheno.owl",
#         "0",
#         "dhbao.owl",
#         "0",
#         "dicom.nema.org",
#         "0",
#         "dideo.owl",
#         "0",
#         "disdriv.owl",
#         "0",
#         "doid.owl",
#         "0",
#         "dpo.owl",
#         "0",
#         "dron.owl",
#         "0",
#         "duo.owl",
#         "0",
#         "ecao.owl",
#         "0",
#         "eco.owl",
#         "0",
#         "ecocore.owl",
#         "0",
#         "ecto.owl",
#         "0",
#         "edamontology.org",
#         "0"
#       ],
#       "isObsolete": [
#         "false",
#         "77227",
#         "true",
#         "0"
#       ],
#       "type": [
#         "class",
#         "77227",
#         "entity",
#         "77227",
#         "annotationproperty",
#         "0",
#         "dataproperty",
#         "0",
#         "individual",
#         "0",
#         "objectproperty",
#         "0",
#         "ontology",
#         "0",
#         "property",
#         "0"
#       ]
#     }
#   }
# }

# %% [markdown]
# First attempt to consolidate into working subfunctions.

# %%
def retrieve_ontology_matches(term, numresults=50, ontology=None):
    """
    Retrieve ontology matches for a given term using OLS API

    params:
    - term (str) - a search term
    - ontologies (list) - a list of ontology names to search.
                            If not provided, all ontologies will be searched.   
    """
    base_url = 'https://www.ebi.ac.uk/ols4/api/search'
    # term = "alzheimer's"

    params = {
        'q': term,
        'rows': numresults,  
    }
    if ontology is not None:
        params['ontology'] = ontology

    try:
        # Make the API request
        response = requests.get(base_url, params=params)
        
        # Raise an exception for bad responses
        response.raise_for_status()
        
        # Parse the JSON results with full details
        results = response.json()

        jsonresults = json.dumps(results, indent=2)
        
        # Extract detailed concept information
        ontology_matches = []
        for term_info in results.get('response', {}).get('docs', []):
            # print(term_info)
            concept = {
                'label': term_info.get('label', 'No Label'),
                'iri': term_info.get('iri', 'No IRI'),
                'description': term_info.get('description', 'No Description'),
                'ontology_name': term_info.get('ontology_name', 'No Ontology Name'),
                'short_form': term_info.get('short_form', 'No Short Form')
            }
            ontology_matches.append(concept)

        return jsonresults, ontology_matches

    except requests.RequestException as e:
        print(f"Error connecting to OLS API: {e}")

def get_term_ancestors(ontology, iri):
    """
    Get ontology term properties using OLS API

    params:
    - ontology (str) - the ontology name
    - iri (str) - the IRI of the term

    returns:
    - ancestors (list) - list of ancestors, each with a dictionary of term properties

    Here is an example of a valid request:
    https://www.ebi.ac.uk/ols4/api/ontologies/duo/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDUO_0000017/ancestors?lang=en
    """
    
    
    # double quote here if we're passing it directly into the URL
    # single quote if we're passing as param
    iri_encoded = quote(quote(iri, safe=''))
    
    # print(f"Attempting to get ancestors for {iri_encoded}")

    url = f"https://www.ebi.ac.uk/ols4/api/ontologies/{ontology}/terms/{iri_encoded}/ancestors"
    params = {
        'lang': 'en'
    }

    try:
        # Make the API request
        response = requests.get(url, params=params)
        
        # Raise an exception for bad responses
        response.raise_for_status()
        
        # Parse the JSON results with full details
        result = response.json()

        # get the ancestors
        ancestors = [i for i in result.get('_embedded', {}).get('terms', [])]
        
        return ancestors

    except requests.RequestException as e:
        
        print(f"Error connecting to OLS API: {e}")

        return e

def rank_ontology_matches(ontology_matches):
    """
    Rank ontology matches

    Criteria for ranking:
    - relevance
    - abstraction (highest level that makes sense)
        - likely depends on get_ontology_term_properties to get the hierarchy

    params:
    - ontology_matches (list) - a list of ontology matches

    returns:
    - ranked_matches (list) - a list of ranked ontology matches
    """
    return ranked_matches

def get_ontology_term_properties(ontology, iri):
    """
    Get ontology term properties using OLS API

    params:
    - ontology (str) - the ontology name
    - iri (str) - the IRI of the term

    returns:
    - term_properties (dict) - a dictionary of term properties

    This is still broken. Fails with 500 Error Code with message "Expected at least 1 result for solr getFirst"
    Can confirm the IRI is properly encoded.
    """
    
    # double quote here if we're passing it directly into the URL
    # single quote if we're passing as param
    iri = quote(quote(iri, safe=''))

    url = f"https://www.ebi.ac.uk/ols4/api/ontologies/{ontology}/properties/{iri}"
    params = {
        # 'rows': 20,  # Increased rows
        # 'iri': iri,
        'lang': 'en'
    }

    try:
        # Make the API request
        response = requests.get(url, params=params)
        
        # Raise an exception for bad responses
        response.raise_for_status()
        
        # Parse the JSON results with full details
        term_properties = response.json()
        
        return term_properties

    except requests.RequestException as e:
        print(f"Error connecting to OLS API: {e}")

# %%
import time

# get initial set of ontology matches
term = "alzheimer's"
jsonresults, matches = retrieve_ontology_matches(term, numresults=50)

# then get the distance from root for each one
# which is just the length of the ancestors list
matches_with_metadata = []
for idx, match in enumerate(matches):
    
    # get ancestors
    iri = match['iri']
    ontology = match['ontology_name']
    ancestors = get_term_ancestors(ontology, iri)
    print(f"Retrieved {len(ancestors)} ancestors for {iri}")

    # update match with ancestor info
    match['ancestors'] = ancestors
    match['distance_from_root'] = len(ancestors)

    matches_with_metadata.append(match)

    # pause for a bit
    # so we don't get rate limited
    time.sleep(1)
# Out:
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F26929004
# Retrieved 20 ancestors for http://snomed.info/id/26929004
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_10652
# Retrieved 6 ancestors for http://purl.obolibrary.org/obo/DOID_10652
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C2866
# Retrieved 15 ancestors for http://purl.obolibrary.org/obo/NCIT_C2866
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F230269008
# Retrieved 20 ancestors for http://snomed.info/id/230269008
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0080348
# Retrieved 11 ancestors for http://purl.obolibrary.org/obo/DOID_0080348
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110035
# Retrieved 11 ancestors for http://purl.obolibrary.org/obo/DOID_0110035
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110036
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110036
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110037
# Retrieved 11 ancestors for http://purl.obolibrary.org/obo/DOID_0110037
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110038
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110038
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110039
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110039
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110040
# Retrieved 11 ancestors for http://purl.obolibrary.org/obo/DOID_0110040
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110041
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110041
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110042
# Retrieved 11 ancestors for http://purl.obolibrary.org/obo/DOID_0110042
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110043
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110043
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110044
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110044
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110045
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110045
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110046
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110046
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110047
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110047
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110048
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110048
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110049
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110049
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110050
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110050
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0110051
# Retrieved 7 ancestors for http://purl.obolibrary.org/obo/DOID_0110051
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_0111364
# Retrieved 11 ancestors for http://purl.obolibrary.org/obo/DOID_0111364
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C123412
# Retrieved 16 ancestors for http://purl.obolibrary.org/obo/NCIT_C123412
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C123413
# Retrieved 16 ancestors for http://purl.obolibrary.org/obo/NCIT_C123413
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C195947
# Retrieved 4 ancestors for http://purl.obolibrary.org/obo/NCIT_C195947
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C146894
# Retrieved 16 ancestors for http://purl.obolibrary.org/obo/NCIT_C146894
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C169104
# Retrieved 16 ancestors for http://purl.obolibrary.org/obo/NCIT_C169104
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FPW_0000015
# Retrieved 4 ancestors for http://purl.obolibrary.org/obo/PW_0000015
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F394877006
# Retrieved 11 ancestors for http://snomed.info/id/394877006
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F230279005
# Retrieved 20 ancestors for http://snomed.info/id/230279005
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F141991000119109
# Retrieved 20 ancestors for http://snomed.info/id/141991000119109
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F161108005
# Retrieved 8 ancestors for http://snomed.info/id/161108005
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C38778
# Retrieved 3 ancestors for http://purl.obolibrary.org/obo/NCIT_C38778
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C39177
# Retrieved 3 ancestors for http://purl.obolibrary.org/obo/NCIT_C39177
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FOAE_0007352
# Retrieved 9 ancestors for http://purl.obolibrary.org/obo/OAE_0007352
# Attempting to get ancestors for http%253A%252F%252Fwww.ebi.ac.uk%252Fefo%252FEFO_0006514
# Retrieved 4 ancestors for http://www.ebi.ac.uk/efo/EFO_0006514
# Attempting to get ancestors for http%253A%252F%252Fwww.ebi.ac.uk%252Fefo%252FEFO_0006801
# Retrieved 9 ancestors for http://www.ebi.ac.uk/efo/EFO_0006801
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F273269001
# Retrieved 3 ancestors for http://snomed.info/id/273269001
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F97751000119108
# Retrieved 20 ancestors for http://snomed.info/id/97751000119108
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F230280008
# Retrieved 20 ancestors for http://snomed.info/id/230280008
# Attempting to get ancestors for http%253A%252F%252Fsnomed.info%252Fid%252F142001000119106
# Retrieved 20 ancestors for http://snomed.info/id/142001000119106
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FADO_0000025
# Retrieved 4 ancestors for http://purl.obolibrary.org/obo/ADO_0000025
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FADO_0000032
# Retrieved 4 ancestors for http://purl.obolibrary.org/obo/ADO_0000032
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FADO_0000042
# Retrieved 4 ancestors for http://purl.obolibrary.org/obo/ADO_0000042
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FADO_0000048
# Retrieved 15 ancestors for http://purl.obolibrary.org/obo/ADO_0000048
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FADO_0000050
# Retrieved 15 ancestors for http://purl.obolibrary.org/obo/ADO_0000050
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FGECKO_0000134
# Retrieved 5 ancestors for http://purl.obolibrary.org/obo/GECKO_0000134
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C195945
# Retrieved 4 ancestors for http://purl.obolibrary.org/obo/NCIT_C195945
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FNCIT_C195946
# Retrieved 4 ancestors for http://purl.obolibrary.org/obo/NCIT_C195946

# %%
# sort by distance from root
matches_with_metadata.sort(key=lambda x: x['distance_from_root'])
# and print out
for idx, match in enumerate(matches_with_metadata, 1):
    print(f"\nResult {idx}:")
    print(f"Label: {match['label']}")
    print(f"IRI: {match['iri']}")
    print(f"Ontology Name: {match['ontology_name']}")
    print(f"Description: {match['description']}")
    print(f"Short Form: {match['short_form']}")
    print(f"Distance from Root: {match['distance_from_root']}")
# Out:
# Result 1:
# Label: Alzheimer's Disease Pathway KEGG
# IRI: http://purl.obolibrary.org/obo/NCIT_C38778
# Ontology Name: ncit
# Description: []
# Short Form: NCIT_C38778
# Distance from Root: 3
#
# Result 2:
# Label: Alzheimer's Disease Pathway BioCarta
# IRI: http://purl.obolibrary.org/obo/NCIT_C39177
# Ontology Name: ncit
# Description: []
# Short Form: NCIT_C39177
# Distance from Root: 3
#
# Result 3:
# Label: Alzheimer's Disease Assessment Scale
# IRI: http://snomed.info/id/273269001
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_273269001
# Distance from Root: 3
#
# Result 4:
# Label: Other Alzheimer's Disease
# IRI: http://purl.obolibrary.org/obo/NCIT_C195947
# Ontology Name: ncit
# Description: ["Evidence of other Alzheimer's disease not specified elsewhere."]
# Short Form: NCIT_C195947
# Distance from Root: 4
#
# Result 5:
# Label: Alzheimer's disease pathway
# IRI: http://purl.obolibrary.org/obo/PW_0000015
# Ontology Name: pw
# Description: ['A mostly sporadic, late-onset condition affecting the central nervous system, that is the most prevalent neurodegenerative disease and the most common form of dementia. It is characterized by the presence of amyloid plaques and fibril tangles. Possible pathways affected range from protein mis-folding and aggregation, to oxidative stress and impaired metal homeostasis.']
# Short Form: PW_0000015
# Distance from Root: 4
#
# Result 6:
# Label: Alzheimer's disease biomarker measurement
# IRI: http://www.ebi.ac.uk/efo/EFO_0006514
# Ontology Name: efo
# Description: ["Alzheimer's disease biomarkers are used as indicators for Alzheimer's disease screening and as predictors for therapeutic responses and prognoses in Alzheimer patients"]
# Short Form: EFO_0006514
# Distance from Root: 4
#
# Result 7:
# Label: Early-stage Alzheimer's Disease (mild)
# IRI: http://purl.obolibrary.org/obo/ADO_0000025
# Ontology Name: ado
# Description: ['A disease stage at which a person may function independently. He or she may still drive, work and be a part of social activities. Despite this, the person may feel as if he or she is having memory lapses, such as forgetting familiar words or the location of everyday objects.']
# Short Form: ADO_0000025
# Distance from Root: 4
#
# Result 8:
# Label: Middle-stage Alzheimer's Disease (moderate)
# IRI: http://purl.obolibrary.org/obo/ADO_0000032
# Ontology Name: ado
# Description: ['A disease in the middle stage where the dementia symptoms are more pronounced. The person may confuse words, get frustrated or angry, and act in unexpected ways, such as refusing to bathe. Damage to nerve cells in the brain can also make it difficult for the person to express thoughts and perform routine tasks without assistance.']
# Short Form: ADO_0000032
# Distance from Root: 4
#
# Result 9:
# Label: Late-stage Alzheimer's Disease(severe)
# IRI: http://purl.obolibrary.org/obo/ADO_0000042
# Ontology Name: ado
# Description: ['A disease at late stage where dementia symptoms are severe. Individuals lose the ability to respond to their environment, to carry on a conversation and, eventually, to control movement. They may still say words or phrases, but communicating pain becomes difficult. As memory and cognitive skills continue to worsen, significant personality changes may take place and individuals need extensive care.']
# Short Form: ADO_0000042
# Distance from Root: 4
#
# Result 10:
# Label: Alzheimer's Disease with Early Onset
# IRI: http://purl.obolibrary.org/obo/NCIT_C195945
# Ontology Name: ncit
# Description: ["Evidence of Alzheimer's disease with early onset."]
# Short Form: NCIT_C195945
# Distance from Root: 4
#
# Result 11:
# Label: Alzheimer's Disease with Late Onset
# IRI: http://purl.obolibrary.org/obo/NCIT_C195946
# Ontology Name: ncit
# Description: ["Evidence of Alzheimer's disease with late onset."]
# Short Form: NCIT_C195946
# Distance from Root: 4
#
# Result 12:
# Label: Alzheimer's Disease Assessment Scale score
# IRI: http://purl.obolibrary.org/obo/GECKO_0000134
# Ontology Name: gecko
# Description: ["A cognitive measurement that is an output (score) from the Alzheimer's Disease Assessment Scale."]
# Short Form: GECKO_0000134
# Distance from Root: 5
#
# Result 13:
# Label: Alzheimer's disease
# IRI: http://purl.obolibrary.org/obo/DOID_10652
# Ontology Name: doid
# Description: ['A tauopathy that is characterized by memory lapses, confusion, emotional instability and progressive loss of mental ability and results in progressive memory loss, impaired thinking, disorientation, and changes in personality and mood starting and leads in advanced cases to a profound decline in cognitive and physical functioning and is marked histologically by the degeneration of brain neurons especially in the cerebral cortex and by the presence of neurofibrillary tangles and plaques containing beta-amyloid.', 'Xref MGI.\nOMIM mapping confirmed by DO. [SN].']
# Short Form: DOID_10652
# Distance from Root: 6
#
# Result 14:
# Label: Alzheimer's disease 16
# IRI: http://purl.obolibrary.org/obo/DOID_0110036
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with a risk allele in in the PCDH11X gene on chromosome Xq21.3."]
# Short Form: DOID_0110036
# Distance from Root: 7
#
# Result 15:
# Label: Alzheimer's disease 6
# IRI: http://purl.obolibrary.org/obo/DOID_0110038
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 10q24."]
# Short Form: DOID_0110038
# Distance from Root: 7
#
# Result 16:
# Label: Alzheimer's disease 7
# IRI: http://purl.obolibrary.org/obo/DOID_0110039
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 10p13."]
# Short Form: DOID_0110039
# Distance from Root: 7
#
# Result 17:
# Label: Alzheimer's disease 8
# IRI: http://purl.obolibrary.org/obo/DOID_0110041
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 20p12.2-q11.21."]
# Short Form: DOID_0110041
# Distance from Root: 7
#
# Result 18:
# Label: Alzheimer's disease 10
# IRI: http://purl.obolibrary.org/obo/DOID_0110043
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 7q36."]
# Short Form: DOID_0110043
# Distance from Root: 7
#
# Result 19:
# Label: Alzheimer's disease 11
# IRI: http://purl.obolibrary.org/obo/DOID_0110044
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 9p22.1."]
# Short Form: DOID_0110044
# Distance from Root: 7
#
# Result 20:
# Label: Alzheimer's disease 12
# IRI: http://purl.obolibrary.org/obo/DOID_0110045
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 8p12-q22."]
# Short Form: DOID_0110045
# Distance from Root: 7
#
# Result 21:
# Label: Alzheimer's disease 13
# IRI: http://purl.obolibrary.org/obo/DOID_0110046
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 1q21."]
# Short Form: DOID_0110046
# Distance from Root: 7
#
# Result 22:
# Label: Alzheimer's disease 14
# IRI: http://purl.obolibrary.org/obo/DOID_0110047
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 1q25."]
# Short Form: DOID_0110047
# Distance from Root: 7
#
# Result 23:
# Label: Alzheimer's disease 15
# IRI: http://purl.obolibrary.org/obo/DOID_0110048
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variations in the region 3q22-q24."]
# Short Form: DOID_0110048
# Distance from Root: 7
#
# Result 24:
# Label: Alzheimer's disease 17
# IRI: http://purl.obolibrary.org/obo/DOID_0110049
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with mutations in the gene TREM2."]
# Short Form: DOID_0110049
# Distance from Root: 7
#
# Result 25:
# Label: Alzheimer's disease 18
# IRI: http://purl.obolibrary.org/obo/DOID_0110050
# Ontology Name: doid
# Description: ["An Alzheimer's disease that has_material_basis_in a mutation in the ADAM10 gene on chromosome 15q21."]
# Short Form: DOID_0110050
# Distance from Root: 7
#
# Result 26:
# Label: Alzheimer's disease 19
# IRI: http://purl.obolibrary.org/obo/DOID_0110051
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by associated variants of the gene PLD3."]
# Short Form: DOID_0110051
# Distance from Root: 7
#
# Result 27:
# Label: Alzheimer's disease society member
# IRI: http://snomed.info/id/161108005
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_161108005
# Distance from Root: 8
#
# Result 28:
# Label: dementia alzheimer's type AE
# IRI: http://purl.obolibrary.org/obo/OAE_0007352
# Ontology Name: oae
# Description: ['This is an AE which is a neurodegenerative disease that usually starts slowly and progressively worsens.']
# Short Form: OAE_0007352
# Distance from Root: 9
#
# Result 29:
# Label: Alzheimer's disease neuropathologic change
# IRI: http://www.ebi.ac.uk/efo/EFO_0006801
# Ontology Name: efo
# Description: ["degenerative change that occurs in individuals with Alzheimer's disease, such as amyloid plaques, cerebral amyloid angiopathy, neurofibrillary tangles, neuronal loss or synaptic loss"]
# Short Form: EFO_0006801
# Distance from Root: 9
#
# Result 30:
# Label: Alzheimer's disease 1
# IRI: http://purl.obolibrary.org/obo/DOID_0080348
# Ontology Name: doid
# Description: ["An Alzheimer's disease that has_material_basis_in mutation heterozygous mutation in the APP gene, which encodes the amyloid precursor protein, on chromosome 21q21."]
# Short Form: DOID_0080348
# Distance from Root: 11
#
# Result 31:
# Label: Alzheimer's disease 2
# IRI: http://purl.obolibrary.org/obo/DOID_0110035
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an association of the apolipoprotein E E4 allele."]
# Short Form: DOID_0110035
# Distance from Root: 11
#
# Result 32:
# Label: Alzheimer's disease 5
# IRI: http://purl.obolibrary.org/obo/DOID_0110037
# Ontology Name: doid
# Description: ["An Alzheimer's disease that is characterized by an associated with variation in the region 12p11.23-q13.12."]
# Short Form: DOID_0110037
# Distance from Root: 11
#
# Result 33:
# Label: Alzheimer's disease 4
# IRI: http://purl.obolibrary.org/obo/DOID_0110040
# Ontology Name: doid
# Description: ["An Alzheimer's disease that has_material_basis_in a mutation in the presenilin-2 gene (PSEN2) on chromosome 1q42."]
# Short Form: DOID_0110040
# Distance from Root: 11
#
# Result 34:
# Label: Alzheimer's disease 3
# IRI: http://purl.obolibrary.org/obo/DOID_0110042
# Ontology Name: doid
# Description: ["An Alzheimer's disease that has_material_basis_in mutation in the presenilin-1 gene (PSEN1) on chromosome 14q24."]
# Short Form: DOID_0110042
# Distance from Root: 11
#
# Result 35:
# Label: Alzheimer's disease 9
# IRI: http://purl.obolibrary.org/obo/DOID_0111364
# Ontology Name: doid
# Description: ["An Alzheimer's disease that has_material_basis_in heterozygous mutation in the ABCA7 gene on chromosome 19p13.3."]
# Short Form: DOID_0111364
# Distance from Root: 11
#
# Result 36:
# Label: FH: Alzheimer's disease
# IRI: http://snomed.info/id/394877006
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_394877006
# Distance from Root: 11
#
# Result 37:
# Label: Alzheimer's Disease
# IRI: http://purl.obolibrary.org/obo/NCIT_C2866
# Ontology Name: ncit
# Description: ['A progressive, neurodegenerative disease characterized by loss of function and death of nerve cells in several areas of the brain leading to loss of cognitive function such as memory and language.']
# Short Form: NCIT_C2866
# Distance from Root: 15
#
# Result 38:
# Label: preclinical stage of Alzheimer's disease
# IRI: http://purl.obolibrary.org/obo/ADO_0000048
# Ontology Name: ado
# Description: ["A disease stage of Alzheimer's disease that begins long before any symptoms become apparent. The symptoms go unnoticed by the patients and people around them and this stage can last for years, possibly even decades."]
# Short Form: ADO_0000048
# Distance from Root: 15
#
# Result 39:
# Label: dementia due to Alzheimer's disease
# IRI: http://purl.obolibrary.org/obo/ADO_0000050
# Ontology Name: ado
# Description: ['A disease of which the patient at this stage suffer from memory loss, impaired ability to think, or making decisions that interferes with doing everyday activities.']
# Short Form: ADO_0000050
# Distance from Root: 15
#
# Result 40:
# Label: Alzheimer's Disease 3
# IRI: http://purl.obolibrary.org/obo/NCIT_C123412
# Ontology Name: ncit
# Description: ["Alzheimer's disease with an early onset (starts before the age of 65). It is caused by mutations in the PSEN1 gene."]
# Short Form: NCIT_C123412
# Distance from Root: 16
#
# Result 41:
# Label: Alzheimer's Disease 4
# IRI: http://purl.obolibrary.org/obo/NCIT_C123413
# Ontology Name: ncit
# Description: ["Alzheimer's disease with an early onset (starts before the age of 65). It is caused by mutations in the PSEN2 gene."]
# Short Form: NCIT_C123413
# Distance from Root: 16
#
# Result 42:
# Label: Alzheimer's Disease 1
# IRI: http://purl.obolibrary.org/obo/NCIT_C146894
# Ontology Name: ncit
# Description: ["Alzheimer's disease caused by mutation(s) in the APP gene, encoding amyloid-beta A4 protein. The onset of this condition typically occurs before age 65."]
# Short Form: NCIT_C146894
# Distance from Root: 16
#
# Result 43:
# Label: Alzheimer's Disease 17
# IRI: http://purl.obolibrary.org/obo/NCIT_C169104
# Ontology Name: ncit
# Description: ["A form of Alzheimer's disease associated with mutation(s) in the TREM2 gene, encoding triggering receptor expressed on myeloid cells 2."]
# Short Form: NCIT_C169104
# Distance from Root: 16
#
# Result 44:
# Label: Alzheimer's disease
# IRI: http://snomed.info/id/26929004
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_26929004
# Distance from Root: 20
#
# Result 45:
# Label: Focal Alzheimer's disease
# IRI: http://snomed.info/id/230269008
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230269008
# Distance from Root: 20
#
# Result 46:
# Label: Non-Alzheimer's progressive dysphasia
# IRI: http://snomed.info/id/230279005
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230279005
# Distance from Root: 20
#
# Result 47:
# Label: Delusions in Alzheimer's disease
# IRI: http://snomed.info/id/141991000119109
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_141991000119109
# Distance from Root: 20
#
# Result 48:
# Label: Altered behavior in Alzheimer's disease (disorder)
# IRI: http://snomed.info/id/97751000119108
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_97751000119108
# Distance from Root: 20
#
# Result 49:
# Label: Progressive aphasia in Alzheimer's disease
# IRI: http://snomed.info/id/230280008
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_230280008
# Distance from Root: 20
#
# Result 50:
# Label: Depressed mood in Alzheimer's disease
# IRI: http://snomed.info/id/142001000119106
# Ontology Name: snomed
# Description: []
# Short Form: SNOMED_142001000119106
# Distance from Root: 20

# %%
def get_term_ancestors(ontology, iri):
    """
    Get ontology term properties using OLS API

    params:
    - ontology (str) - the ontology name
    - iri (str) - the IRI of the term

    returns:
    - term_properties (dict) - a dictionary of term properties

    Here is an example of a valid request:
    https://www.ebi.ac.uk/ols4/api/ontologies/duo/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDUO_0000017/ancestors?lang=en
    """
    
    
    # make sure the IRI is double encoded
    iri_encoded = quote(quote(iri, safe=''))
    
    print(f"Attempting to get ancestors for {iri_encoded}")

    url = f"https://www.ebi.ac.uk/ols4/api/ontologies/{ontology}/terms/{iri_encoded}/ancestors"
    params = {
        'lang': 'en'
    }

    try:
        # Make the API request
        response = requests.get(url, params=params)
        
        # Raise an exception for bad responses
        response.raise_for_status()
        
        # Parse the JSON results with full details
        term_properties = response.json()
        
        return term_properties

    except requests.RequestException as e:
        
        print(f"Error connecting to OLS API: {e}")

        return e

iri = "http://purl.obolibrary.org/obo/DOID_10652"
ontology = "doid"
# iri = "http://purl.obolibrary.org/obo/DUO_0000017"
# ontology = "duo"
result = get_term_ancestors(ontology, iri)
print(json.dumps(result, indent=2))
# Out:
# http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_10652
# Attempting to get ancestors for http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_10652
# {
#   "_embedded": {
#     "terms": [
#       {
#         "iri": "http://purl.obolibrary.org/obo/DOID_680",
#         "lang": "en",
#         "description": [
#           "A neurodegenerative disease that has_material_basis_in the pathological aggregation of tau protein in so-called neurofibrillary tangles (NFT) in the human brain."
#         ],
#         "synonyms": [],
#         "annotation": {
#           "has_dbxref": [
#             "MESH:D024801",
#             "UMLS_CUI:C0949664"
#           ],
#           "has_obo_namespace": [
#             "disease_ontology"
#           ],
#           "id": [
#             "DOID:680"
#           ]
#         },
#         "label": "tauopathy",
#         "ontology_name": "doid",
#         "ontology_prefix": "DOID",
#         "ontology_iri": "http://purl.obolibrary.org/obo/doid.owl",
#         "is_obsolete": false,
#         "term_replaced_by": null,
#         "is_defining_ontology": true,
#         "has_children": true,
#         "is_root": false,
#         "short_form": "DOID_680",
#         "obo_id": "DOID:680",
#         "in_subset": [
#           "DO_FlyBase_slim"
#         ],
#         "obo_definition_citation": [
#           {
#             "definition": "A neurodegenerative disease that has_material_basis_in the pathological aggregation of tau protein in so-called neurofibrillary tangles (NFT) in the human brain.",
#             "oboXrefs": [
#               {
#                 "database": "url",
#                 "id": "http",
#                 "description": null,
#                 "url": null
#               }
#             ]
#           }
#         ],
#         "obo_xref": [
#           {
#             "database": "MESH",
#             "id": "D024801",
#             "description": null,
#             "url": "http://id.nlm.nih.gov/mesh/D024801"
#           },
#           {
#             "database": "UMLS_CUI",
#             "id": "C0949664",
#             "description": null,
#             "url": "https://uts.nlm.nih.gov/uts/umls/concept/C0949664"
#           }
#         ],
#         "obo_synonym": null,
#         "is_preferred_root": false,
#         "_links": {
#           "self": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680?lang=en"
#           },
#           "parents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/parents"
#           },
#           "ancestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/ancestors"
#           },
#           "hierarchicalParents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/hierarchicalParents"
#           },
#           "hierarchicalAncestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/hierarchicalAncestors"
#           },
#           "jstree": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/jstree"
#           },
#           "children": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/children"
#           },
#           "descendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/descendants"
#           },
#           "hierarchicalChildren": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/hierarchicalChildren"
#           },
#           "hierarchicalDescendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/hierarchicalDescendants"
#           },
#           "graph": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_680/graph"
#           }
#         }
#       },
#       {
#         "iri": "http://purl.obolibrary.org/obo/DOID_1289",
#         "lang": "en",
#         "description": [
#           "A central nervous system disease that results in the progressive deterioration of function or structure of neurons."
#         ],
#         "synonyms": [
#           "degenerative disease"
#         ],
#         "annotation": {
#           "has_alternative_id": [
#             "DOID:4874"
#           ],
#           "has_dbxref": [
#             "ICD10CM:G31.9",
#             "MESH:D019636",
#             "NCI:C27090",
#             "SNOMEDCT_US_2023_03_01:362975008",
#             "UMLS_CUI:C0524851",
#             "UMLS_CUI:C1285162"
#           ],
#           "has_obo_namespace": [
#             "disease_ontology"
#           ],
#           "id": [
#             "DOID:1289"
#           ]
#         },
#         "label": "neurodegenerative disease",
#         "ontology_name": "doid",
#         "ontology_prefix": "DOID",
#         "ontology_iri": "http://purl.obolibrary.org/obo/doid.owl",
#         "is_obsolete": false,
#         "term_replaced_by": null,
#         "is_defining_ontology": true,
#         "has_children": true,
#         "is_root": false,
#         "short_form": "DOID_1289",
#         "obo_id": "DOID:1289",
#         "in_subset": [
#           "DO_FlyBase_slim",
#           "NCIthesaurus"
#         ],
#         "obo_definition_citation": [
#           {
#             "definition": "A central nervous system disease that results in the progressive deterioration of function or structure of neurons.",
#             "oboXrefs": [
#               {
#                 "database": "url",
#                 "id": "http",
#                 "description": null,
#                 "url": null
#               },
#               {
#                 "database": "url",
#                 "id": "http",
#                 "description": null,
#                 "url": null
#               }
#             ]
#           }
#         ],
#         "obo_xref": [
#           {
#             "database": "ICD10CM",
#             "id": "G31.9",
#             "description": null,
#             "url": null
#           },
#           {
#             "database": "MESH",
#             "id": "D019636",
#             "description": null,
#             "url": "http://id.nlm.nih.gov/mesh/D019636"
#           },
#           {
#             "database": "NCI",
#             "id": "C27090",
#             "description": null,
#             "url": "http://purl.obolibrary.org/obo/NCIT_C27090"
#           },
#           {
#             "database": "SNOMEDCT_US_2023_03_01",
#             "id": "362975008",
#             "description": null,
#             "url": "http://snomed.info/id/362975008"
#           },
#           {
#             "database": "UMLS_CUI",
#             "id": "C0524851",
#             "description": null,
#             "url": "https://uts.nlm.nih.gov/uts/umls/concept/C0524851"
#           },
#           {
#             "database": "UMLS_CUI",
#             "id": "C1285162",
#             "description": null,
#             "url": "https://uts.nlm.nih.gov/uts/umls/concept/C1285162"
#           }
#         ],
#         "obo_synonym": null,
#         "is_preferred_root": false,
#         "_links": {
#           "self": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289?lang=en"
#           },
#           "parents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/parents"
#           },
#           "ancestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/ancestors"
#           },
#           "hierarchicalParents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/hierarchicalParents"
#           },
#           "hierarchicalAncestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/hierarchicalAncestors"
#           },
#           "jstree": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/jstree"
#           },
#           "children": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/children"
#           },
#           "descendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/descendants"
#           },
#           "hierarchicalChildren": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/hierarchicalChildren"
#           },
#           "hierarchicalDescendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/hierarchicalDescendants"
#           },
#           "graph": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_1289/graph"
#           }
#         }
#       },
#       {
#         "iri": "http://purl.obolibrary.org/obo/DOID_331",
#         "lang": "en",
#         "description": [
#           "A nervous system disease that affects either the spinal cord (myelopathy) or brain (encephalopathy) of the central nervous system."
#         ],
#         "synonyms": [],
#         "annotation": {
#           "has_dbxref": [
#             "ICD10CM:G96.9",
#             "MESH:D002493",
#             "NCI:C2934",
#             "SNOMEDCT_US_2023_03_01:267144009",
#             "UMLS_CUI:C0007682"
#           ],
#           "has_obo_namespace": [
#             "disease_ontology"
#           ],
#           "id": [
#             "DOID:331"
#           ]
#         },
#         "label": "central nervous system disease",
#         "ontology_name": "doid",
#         "ontology_prefix": "DOID",
#         "ontology_iri": "http://purl.obolibrary.org/obo/doid.owl",
#         "is_obsolete": false,
#         "term_replaced_by": null,
#         "is_defining_ontology": true,
#         "has_children": true,
#         "is_root": false,
#         "short_form": "DOID_331",
#         "obo_id": "DOID:331",
#         "in_subset": [
#           "DO_AGR_slim",
#           "DO_CFDE_slim",
#           "DO_GXD_slim",
#           "NCIthesaurus"
#         ],
#         "obo_definition_citation": [
#           {
#             "definition": "A nervous system disease that affects either the spinal cord (myelopathy) or brain (encephalopathy) of the central nervous system.",
#             "oboXrefs": [
#               {
#                 "database": "url",
#                 "id": "http",
#                 "description": null,
#                 "url": null
#               }
#             ]
#           }
#         ],
#         "obo_xref": [
#           {
#             "database": "ICD10CM",
#             "id": "G96.9",
#             "description": null,
#             "url": null
#           },
#           {
#             "database": "MESH",
#             "id": "D002493",
#             "description": null,
#             "url": "http://id.nlm.nih.gov/mesh/D002493"
#           },
#           {
#             "database": "NCI",
#             "id": "C2934",
#             "description": null,
#             "url": "http://purl.obolibrary.org/obo/NCIT_C2934"
#           },
#           {
#             "database": "SNOMEDCT_US_2023_03_01",
#             "id": "267144009",
#             "description": null,
#             "url": "http://snomed.info/id/267144009"
#           },
#           {
#             "database": "UMLS_CUI",
#             "id": "C0007682",
#             "description": null,
#             "url": "https://uts.nlm.nih.gov/uts/umls/concept/C0007682"
#           }
#         ],
#         "obo_synonym": null,
#         "is_preferred_root": false,
#         "_links": {
#           "self": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331?lang=en"
#           },
#           "parents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/parents"
#           },
#           "ancestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/ancestors"
#           },
#           "hierarchicalParents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/hierarchicalParents"
#           },
#           "hierarchicalAncestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/hierarchicalAncestors"
#           },
#           "jstree": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/jstree"
#           },
#           "children": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/children"
#           },
#           "descendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/descendants"
#           },
#           "hierarchicalChildren": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/hierarchicalChildren"
#           },
#           "hierarchicalDescendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/hierarchicalDescendants"
#           },
#           "graph": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_331/graph"
#           }
#         }
#       },
#       {
#         "iri": "http://purl.obolibrary.org/obo/DOID_863",
#         "lang": "en",
#         "description": [
#           "A disease of anatomical entity that is located_in the central nervous system or located_in the peripheral nervous system."
#         ],
#         "synonyms": [],
#         "annotation": {
#           "has_dbxref": [
#             "ICD10CM:G98",
#             "ICD9CM:349.9",
#             "MESH:D009422",
#             "NCI:C26835",
#             "SNOMEDCT_US_2023_03_01:155262005",
#             "UMLS_CUI:C0027765"
#           ],
#           "has_obo_namespace": [
#             "disease_ontology"
#           ],
#           "id": [
#             "DOID:863"
#           ]
#         },
#         "label": "nervous system disease",
#         "ontology_name": "doid",
#         "ontology_prefix": "DOID",
#         "ontology_iri": "http://purl.obolibrary.org/obo/doid.owl",
#         "is_obsolete": false,
#         "term_replaced_by": null,
#         "is_defining_ontology": true,
#         "has_children": true,
#         "is_root": false,
#         "short_form": "DOID_863",
#         "obo_id": "DOID:863",
#         "in_subset": [
#           "DO_CFDE_slim",
#           "DO_GXD_slim",
#           "DO_MGI_slim",
#           "NCIthesaurus"
#         ],
#         "obo_definition_citation": [
#           {
#             "definition": "A disease of anatomical entity that is located_in the central nervous system or located_in the peripheral nervous system.",
#             "oboXrefs": [
#               {
#                 "database": "url",
#                 "id": "http",
#                 "description": null,
#                 "url": null
#               }
#             ]
#           }
#         ],
#         "obo_xref": [
#           {
#             "database": "ICD10CM",
#             "id": "G98",
#             "description": null,
#             "url": "https://icd.codes/icd10cm/G98"
#           },
#           {
#             "database": "ICD9CM",
#             "id": "349.9",
#             "description": null,
#             "url": null
#           },
#           {
#             "database": "MESH",
#             "id": "D009422",
#             "description": null,
#             "url": "http://id.nlm.nih.gov/mesh/D009422"
#           },
#           {
#             "database": "NCI",
#             "id": "C26835",
#             "description": null,
#             "url": "http://purl.obolibrary.org/obo/NCIT_C26835"
#           },
#           {
#             "database": "SNOMEDCT_US_2023_03_01",
#             "id": "155262005",
#             "description": null,
#             "url": "http://snomed.info/id/155262005"
#           },
#           {
#             "database": "UMLS_CUI",
#             "id": "C0027765",
#             "description": null,
#             "url": "https://uts.nlm.nih.gov/uts/umls/concept/C0027765"
#           }
#         ],
#         "obo_synonym": null,
#         "is_preferred_root": false,
#         "_links": {
#           "self": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863?lang=en"
#           },
#           "parents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/parents"
#           },
#           "ancestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/ancestors"
#           },
#           "hierarchicalParents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/hierarchicalParents"
#           },
#           "hierarchicalAncestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/hierarchicalAncestors"
#           },
#           "jstree": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/jstree"
#           },
#           "children": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/children"
#           },
#           "descendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/descendants"
#           },
#           "hierarchicalChildren": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/hierarchicalChildren"
#           },
#           "hierarchicalDescendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/hierarchicalDescendants"
#           },
#           "graph": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_863/graph"
#           }
#         }
#       },
#       {
#         "iri": "http://purl.obolibrary.org/obo/DOID_7",
#         "lang": "en",
#         "description": [
#           "A disease that manifests in a defined anatomical structure."
#         ],
#         "synonyms": [],
#         "annotation": {
#           "has_alternative_id": [
#             "DOID:1",
#             "DOID:2",
#             "DOID:5",
#             "DOID:71",
#             "DOID:72",
#             "DOID:8"
#           ],
#           "has_obo_namespace": [
#             "disease_ontology"
#           ],
#           "id": [
#             "DOID:7"
#           ]
#         },
#         "label": "disease of anatomical entity",
#         "ontology_name": "doid",
#         "ontology_prefix": "DOID",
#         "ontology_iri": "http://purl.obolibrary.org/obo/doid.owl",
#         "is_obsolete": false,
#         "term_replaced_by": null,
#         "is_defining_ontology": true,
#         "has_children": true,
#         "is_root": false,
#         "short_form": "DOID_7",
#         "obo_id": "DOID:7",
#         "in_subset": [
#           "DO_RAD_slim"
#         ],
#         "obo_definition_citation": [
#           {
#             "definition": "A disease that manifests in a defined anatomical structure.",
#             "oboXrefs": [
#               {
#                 "database": "url",
#                 "id": "http",
#                 "description": null,
#                 "url": null
#               }
#             ]
#           }
#         ],
#         "obo_xref": null,
#         "obo_synonym": null,
#         "is_preferred_root": false,
#         "_links": {
#           "self": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7?lang=en"
#           },
#           "parents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/parents"
#           },
#           "ancestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/ancestors"
#           },
#           "hierarchicalParents": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/hierarchicalParents"
#           },
#           "hierarchicalAncestors": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/hierarchicalAncestors"
#           },
#           "jstree": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/jstree"
#           },
#           "children": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/children"
#           },
#           "descendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/descendants"
#           },
#           "hierarchicalChildren": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/hierarchicalChildren"
#           },
#           "hierarchicalDescendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/hierarchicalDescendants"
#           },
#           "graph": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_7/graph"
#           }
#         }
#       },
#       {
#         "iri": "http://purl.obolibrary.org/obo/DOID_4",
#         "lang": "en",
#         "description": [
#           "A disease is a disposition (i) to undergo pathological processes that (ii) exists in an organism because of one or more disorders in that organism."
#         ],
#         "synonyms": [],
#         "annotation": {
#           "has_dbxref": [
#             "MESH:D004194",
#             "NCI:C2991",
#             "SNOMEDCT_US_2023_03_01:64572001",
#             "UMLS_CUI:C0012634"
#           ],
#           "has_obo_namespace": [
#             "disease_ontology"
#           ],
#           "id": [
#             "DOID:4"
#           ]
#         },
#         "label": "disease",
#         "ontology_name": "doid",
#         "ontology_prefix": "DOID",
#         "ontology_iri": "http://purl.obolibrary.org/obo/doid.owl",
#         "is_obsolete": false,
#         "term_replaced_by": null,
#         "is_defining_ontology": true,
#         "has_children": true,
#         "is_root": true,
#         "short_form": "DOID_4",
#         "obo_id": "DOID:4",
#         "in_subset": [
#           "DO_RAD_slim",
#           "NCIthesaurus"
#         ],
#         "obo_definition_citation": [
#           {
#             "definition": "A disease is a disposition (i) to undergo pathological processes that (ii) exists in an organism because of one or more disorders in that organism.",
#             "oboXrefs": [
#               {
#                 "database": "url",
#                 "id": "https",
#                 "description": null,
#                 "url": null
#               }
#             ]
#           }
#         ],
#         "obo_xref": [
#           {
#             "database": "MESH",
#             "id": "D004194",
#             "description": null,
#             "url": "http://id.nlm.nih.gov/mesh/D004194"
#           },
#           {
#             "database": "NCI",
#             "id": "C2991",
#             "description": null,
#             "url": "http://purl.obolibrary.org/obo/NCIT_C2991"
#           },
#           {
#             "database": "SNOMEDCT_US_2023_03_01",
#             "id": "64572001",
#             "description": null,
#             "url": "http://snomed.info/id/64572001"
#           },
#           {
#             "database": "UMLS_CUI",
#             "id": "C0012634",
#             "description": null,
#             "url": "https://uts.nlm.nih.gov/uts/umls/concept/C0012634"
#           }
#         ],
#         "obo_synonym": null,
#         "is_preferred_root": false,
#         "_links": {
#           "self": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_4?lang=en"
#           },
#           "children": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_4/children"
#           },
#           "descendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_4/descendants"
#           },
#           "hierarchicalChildren": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_4/hierarchicalChildren"
#           },
#           "hierarchicalDescendants": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_4/hierarchicalDescendants"
#           },
#           "graph": {
#             "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_4/graph"
#           }
#         }
#       }
#     ]
#   },
#   "_links": {
#     "self": {
#       "href": "https://www.ebi.ac.uk/ols4/api/ontologies/doid/terms/http%253A%252F%252Fpurl.obolibrary.org%252Fobo%252FDOID_10652/ancestors?lang=en&page=0&size=20"
#     }
#   },
#   "page": {
#     "size": 20,
#     "totalElements": 6,
#     "totalPages": 1,
#     "number": 0
#   }
# }

# %%
ancestors = [i for i in result.get('_embedded', {}).get('terms', [])]
len(ancestors)
# Out:
# 6

# %%
for a in ancestors:
    print(a['label'])
    print(f'is_root = {a["is_root"]}')
# Out:
# tauopathy
# is_root = False
# neurodegenerative disease
# is_root = False
# central nervous system disease
# is_root = False
# nervous system disease
# is_root = False
# disease of anatomical entity
# is_root = False
# disease
# is_root = True

# %% [markdown]
# ## Parse out stuff from docx

# %%
result
# Out:
# [{'doc_title': '',
#   'doc_lastauthorname': '',
#   'doc_year': '',
#   'doc_url': '',
#   'doc_peco_section': '',
#   'peco_elements': {'Population': ['patients with suspected malaria'],
#    'Exposure': ['Plasmodium', 'infection'],
#    'Comparator': ['Plasmodium', '-uninfected individuals'],
#    'Outcome': ['blood cortisol levels']}},
#  {'doc_title': '',
#   'doc_lastauthorname': '',
#   'doc_year': '',
#   'doc_url': '',
#   'doc_peco_section': '',
#   'peco_elements': {'Population': ['older population'],
#    'Exposure': ['ambient temperatures'],
#    'Comparator': ['compared to relatively lower or higher temperatures'],
#    'Outcome': ['mortality',
#     'morbidity',
#     'mental and neurological disorders',
#     'extreme temperature events']}}]

# %%
from keybert import KeyBERT
